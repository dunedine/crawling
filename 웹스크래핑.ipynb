# %% [markdown]
# # ch1.웹스크래핑 BeautifulSoup

# %%
# selenium으로 이미지 전체 웹크롤링
from urllib.request import urlopen

url = ('http://pythonscraping.com/pages/page1.html') # 크롤링 대상 페이지
html = urlopen(url)

# html = urlopen('http://pythonscraping.com/pages/page1.html')
# print(html.read())

# %%
html

# %%
# 웹은 request 우리가 보내는거, response 받는거 2가지 구조로 이뤄져있
result = html.read()

# %%
type(result) # bytes 타입
result
# Out:
# b''

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup  # BeautifulSoup만 가지고 크롤링 도전. 이것만으로 안되면 selenium

url = 'http://www.pythonscraping.com/pages/page1.html'
html = urlopen(url)

bs = BeautifulSoup(html.read(), 'html.parser')
bs
# Out:
# <html>
# <head>
# <title>A Useful Page</title>
# </head>
# <body>
# <h1>An Interesting Title</h1>
# <div>
# Lorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.
# </div>
# </body>
# </html>

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
# 예외처리 pages에서 page로 오픈. url이 없는 경우 입력했을 때 내용
url = 'http://www.pythonscraping.com/page/page1.html'
try:
    html = urlopen(url)
    bs = BeautifulSoup(html.read(), 'html.parser')
    title = bs.h1.text
except:
    pass
# 이 경우 try pass 많이써줘야함 실무에서 오류나면 이걸로 런하다가 끊기기 때문

# %%
type(bs)  # bs4.BeautifulSoup 타입 -> html bs 객체
type(bs.h1)   # h1태그를 가져옴, bs4.element.Tag타입
type(bs.h1.text) # str 타입.맨마지막이 text라
print(bs.html.text) # 태그내에 있는 내용을 text타입으로 다 뽑아옴
# Out:
# A Useful Page
#
#
# An Interesting Title
#
# Lorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.

# %%
from urllib.request import urlopen
from urllib.error import HTTPError
from urllib.error import URLError

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
def get_title(url):
    url = url
    try:
        html = urlopen(url)
        bs = BeautifulSoup(html.read(), 'html.parser')
    except:
        return 'url이 없습니다'
    try:
        title = bs.h1.text
    except:
        return 'element(=tag)가 존재하지 않습니다'
    return title

# %%
url = 'http://www.pythonscraping.com/page/page1.html'
get_title(url)
# Out:
# 'url이 없습니다'

# %% [markdown]
# ## ch2

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
url = 'http://www.pythonscraping.com/pages/warandpeace.html'
html = urlopen(url)
bs = BeautifulSoup(html, 'html.parser')

# %%
type(bs.span)
bs.span # element tag는 가장 위에걸 찾아냄. 대칭언어여서.
# bs.span = bs.find('span') 같은 역할. span태그 가져온거나 같

bs.find('span') # element 요소만 가져옴
len(bs.find_all('span')) # element요소 다 가져옴. span태그있는거 다 가져옴
# Out:
# 75

# %%
bs.findAll('span', {'class':'green'}) # <span class='green'>. list

# element를 떼올 수 있다.
# 두번째 인물을 가져오고 싶은 경우
bs.findAll('span', {'class':'green'})[1].text.replace('\n', ' ') # tag

# 녹색 등장인물만 다 가져오고 싶은 경우
bs.findAll('span', {'class':'green'})
actors = []
for actor in bs.find_all('span', {'class':'green'}):
    actors.append(actor.text)
actors

# red 대사 가져오려함
bs.findAll('span', {'class':'red'})
ss = []
for s in bs.find_all('span', {'class':'red'}):
    ss.append(s.text)
ss
# Out:
# ["Well, Prince, so Genoa and Lucca are now just family estates of the\nBuonapartes. But I warn you, if you don't tell me that this means war,\nif you still try to defend the infamies and horrors perpetrated by\nthat Antichrist- I really believe he is Antichrist- I will have\nnothing more to do with you and you are no longer my friend, no longer\nmy 'faithful slave,' as you call yourself! But how do you do? I see\nI have frightened you- sit down and tell me all the news.",
#  'If you have nothing better to do, Count [or Prince], and if the\nprospect of spending an evening with a poor invalid is not too\nterrible, I shall be very charmed to see you tonight between 7 and 10-\nAnnette Scherer.',
#  'Heavens! what a virulent attack!',
#  "First of all, dear friend, tell me how you are. Set your friend's\nmind at rest,",
#  'Can one be well while suffering morally? Can one be calm in times\nlike these if one has any feeling?',
#  'You are\nstaying the whole evening, I hope?',
# ...

# %%
nameList = bs.findAll(text = 'the prince')
print(len(nameList))
# Out:
# 7

# %%
title = bs.find_all(id='title', class_='text')
title
# Out:
# []

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
url = 'http://www.pythonscraping.com/pages/page3.html'
html = urlopen(url)
bs = BeautifulSoup(html, 'html.parser')
bs
# Out:
# <html>
# <head>
# <style>
# img{
# 	width:75px;
# }
# table{
# 	width:50%;
# }
# td{
# 	margin:10px;
# 	padding:10px;
# }
# .wrapper{
# 	width:800px;
# }
# .excitingNote{
# 	font-style:italic;
# 	font-weight:bold;
# }
# </style>
# </head>
# <body>
# <div id="wrapper">
# <img src="../img/gifts/logo.jpg" style="float:left;"/>
# <h1>Totally Normal Gifts</h1>
# <div id="content">Here is a collection of totally normal, totally reasonable gifts that your friends are sure to love! Our collection is
# hand-curated by well-paid, free-range Tibetan monks.<p>
# We haven't figured out how to make online shopping carts yet, but you can send us a check to:<br/>
# 123 Main St.<br/>
# Abuja, Nigeria
# We will then send your totally amazing gift, pronto! Please include an extra $5.00 for gift wrapping.</p></div>
# <table id="giftList">
# <tr><th>
# Item Title
# </th><th>
# Description
# </th><th>
# Cost
# </th><th>
# Image
# </th></tr>
# <tr class="gift" id="gift1"><td>
# Vegetable Basket
# ...

# %%
bs.find('tr', {'class':'gift'}).td.text
for i in bs.findAll('tr', {'class':'gift'}):
    print(i.td.text)
# Out:
# Vegetable Basket
#
#
# Russian Nesting Dolls
#
#
# Fish Painting
#
#
# Dead Parrot
#
#
# Mystery Box

# %%
# 가격만 뽑아내고 싶을 경우
bs.findAll('tr', {'class':'gift'})[0].findAll('td')[2]
for i in bs.findAll('tr',{'class':'gift'}):
    print(i.findAll('td')[2].text)
# Out:
# $15.00
#
#
# $10,000.52
#
#
# $10,005.00
#
#
# $0.50
#
#
# $1.50

# %%
bs.findAll('tr', {'class':'gift'})[0].findAll('td')[1].find('span').text  # type이 bs.element.tag
for i in bs.findAll('tr', {'class':'gift'}):
    print(i.findAll('td')[1].find('span').text)
    #find는 위에거 하나만. findall써야 3개 중에 하나 고름
# Out:
# Now with super-colorful bell peppers!
# 8 entire dolls per set! Octuple the presents!
# Also hand-painted by trained monkeys!
# Or maybe he's only resting?
# Keep your friends guessing!

# %%
bs.find('table',{'id':'giftList'}).findAll('tr')
bs.find('table',{'id':'giftList'}).children

# %%
for i in bs.find('table',{'id':'giftList'}).children:
    try:
        print(i.td.text)
    except:
        pass
    # table에 대한 children -> table아래있는 tr임
# Out:
# Vegetable Basket
#
#
# Russian Nesting Dolls
#
#
# Fish Painting
#
#
# Dead Parrot
#
#
# Mystery Box

# %%
for i in bs.find('table',{'id':'giftList'}).children:
    try:
        print(i.findAll('td')[1].text)
    except:
        pass
# Out:
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# Now with super-colorful bell peppers!
#
#
# Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! 8 entire dolls per set! Octuple the presents!
#
#
# If something seems fishy about this painting, it's because it's a fish! Also hand-painted by trained monkeys!
#
#
# This is an ex-parrot! Or maybe he's only resting?
#
#
# If you love suprises, this mystery box is for you! Do not place on light-colored surfaces. May cause oil staining. Keep your friends guessing!

# %%
for i in  bs.find('table',{'id':'giftList'}).tr.next_siblings: 
    print(i)
#   print(type(i))
#  옆의 형제
# Out:
# <tr class="gift" id="gift1"><td>
# Vegetable Basket
# </td><td>
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# </td><td>
# $15.00
# </td><td>
# <img src="../img/gifts/img1.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift2"><td>
# Russian Nesting Dolls
# </td><td>
# Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>
# </td><td>
# $10,000.52
# </td><td>
# <img src="../img/gifts/img2.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift3"><td>
# Fish Painting
# </td><td>
# If something seems fishy about this painting, it's because it's a fish! <span class="excitingNote">Also hand-painted by trained monkeys!</span>
# </td><td>
# $10,005.00
# </td><td>
# <img src="../img/gifts/img3.jpg"/>
# </td></tr>
#
#
# ...

# %%
bs.find('img', {'src':'../img/gifts/img1.jpg'}).parent.previous_sibling.get_text()
bs.findAll('img')

#  parent -td 태그에는 형제들이 있
#       .parent.previous_sibling.get_text()) # 이전 속성. tr 찾는.  이전형제 찾아서 속성 넘겨주는거
# Out:
# [<img src="../img/gifts/logo.jpg" style="float:left;"/>,
#  <img src="../img/gifts/img1.jpg"/>,
#  <img src="../img/gifts/img2.jpg"/>,
#  <img src="../img/gifts/img3.jpg"/>,
#  <img src="../img/gifts/img4.jpg"/>,
#  <img src="../img/gifts/img6.jpg"/>]

# %%
bs.findAll('td')[6]
# 이미지 td
# Out:
# <td>
# $10,000.52
# </td>

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

html = urlopen('http://www.pythonscraping.com/pages/page3.html')
bs = BeautifulSoup(html, 'html.parser')
images = bs.find_all('img', {'src':re.compile('\.\.\/img\/gifts/img.*\.jpg')})
# \.\. 특수문자 인식 x -> '../img'로 그대로 인식
for image in images: 
    print(image['src'])
    
    # 정규식은 chatgpt에 물어보세여
# Out:
# ../img/gifts/img1.jpg
# ../img/gifts/img2.jpg
# ../img/gifts/img3.jpg
# ../img/gifts/img4.jpg
# ../img/gifts/img6.jpg

# %%
bs.find_all(lambda tag: len(tag.attrs) == 2) # tag의 attribute가 2보다 큰 거
bs.html.div.attrs
len(bs.html.div.img.attrs) == 2

bs.find_all(lambda tag: len(tag.attrs) == 2)
bs.find_all(lambda tag: 'src' in tag.attrs.keys())
for image in images:
    image['src']

# 'src' in bs.html.div.img

# %%
bs.find_all('', text='Or maybe he\'s only resting')
# Out:
# []

# %% [markdown]
# ## ch3.

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup 

url = "http://localhost:8000/aaa/"
html = urlopen(url)
bs = BeautifulSoup(html, 'html.parser')
bs
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>Document</title>
# </head>
# <body>
# <li><a href="https//naver.com">네이버</a></li>
# <li><a href="https//daum.net">다음</a></li>
# <li><a href="https://www.donga.com/" style="color: red">동아일보</a></li>
# </body>
# </html>

# %%
for link in bs.find_all('a'):
    print(link.text)
    
for link in bs.find_all('a'):
    print(link['href'])
    
for link in bs.find_all('a'):
    try:
        print(link['style'])
    except:
        pass
# Out:
# 네이버
# 다음
# 동아일보
# https//naver.com
# https//daum.net
# https://www.donga.com/
# color: red

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup 

url = 'http://en.wikipedia.org/wiki/Kevin_Bacon'
html = urlopen(url)
bs = BeautifulSoup(html, 'html.parser')
links = []
for link in bs.find_all('a'):
    if 'href' in link.attrs:
        links.append(link.attrs['href'])

# %%
url + links[1]
# Out:
# 'http://en.wikipedia.org/wiki/Kevin_Bacon/wiki/Main_Page'

# %%
inner_link = []
outer_link = []
for link in links:
    if 'http' in link:
        outer_link.append(link)
    else:
        inner_link.append(link)

# %%
outer_link
# Out:
# ['https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en',
#  'https://af.wikipedia.org/wiki/Kevin_Bacon',
#  'https://ar.wikipedia.org/wiki/%D9%83%D9%8A%D9%81%D9%8A%D9%86_%D8%A8%D9%8A%D9%83%D9%86',
#  'https://an.wikipedia.org/wiki/Kevin_Bacon',
#  'https://ast.wikipedia.org/wiki/Kevin_Bacon',
#  'https://azb.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86',
#  'https://zh-min-nan.wikipedia.org/wiki/Kevin_Bacon',
#  'https://bi.wikipedia.org/wiki/Kevin_Bacon',
#  'https://bg.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D1%8A%D0%BD',
#  'https://bs.wikipedia.org/wiki/Kevin_Bacon',
#  'https://ca.wikipedia.org/wiki/Kevin_Bacon',
#  'https://cs.wikipedia.org/wiki/Kevin_Bacon',
#  'https://da.wikipedia.org/wiki/Kevin_Bacon',
#  'https://de.wikipedia.org/wiki/Kevin_Bacon',
# ...

# %%
from urllib.request import urlopen 
from bs4 import BeautifulSoup 
import re

url = 'http://en.wikipedia.org/wiki/Kevin_Bacon'
html = urlopen(url)
bs = BeautifulSoup(html, 'html.parser')

for link in bs.find('div', {'id':'bodyContent'}).find_all(
    'a', href=re.compile('^(/wiki/)((?!:).)*$')): # ^시작이 wiki 아무말이나 와도 좋다 끝이$
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/Philadelphia
# /wiki/Kevin_Bacon_filmography
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Holly_Near
# /wiki/Leading_man
# /wiki/Character_actor
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/The_Guardian
# /wiki/Academy_Award
# /wiki/Hollywood_Walk_of_Fame
# /wiki/National_Lampoon%27s_Animal_House
# /wiki/Footloose_(1984_film)
# /wiki/Diner_(1982_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Frost/Nixon_(film)
# /wiki/Friday_the_13th_(1980_film)
# /wiki/The_River_Wild
# /wiki/Sleepers_(film)
# /wiki/Wild_Things_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Flatliners
# /wiki/Crazy,_Stupid,_Love
# /wiki/Black_Mass_(film)
# /wiki/Patriots_Day_(film)
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# ...

# %%
# 재귀 함수 
## Recursively crawling an entire site
from urllib.request import urlopen
from bs4 import BeautifulSoup
'Kevin_Bacon'

def get_link(url):
    base_url = 'http://en.wikipedia.org/wiki/'
    url = base_url + url
    html = urlopen(url)
    bs = BeautifulSoup(html, 'html.parser')
    inner_links = bs.find_all('a', href=re.compile('^(/wiki/)'))
    inner_href = []

    for inner_link in inner_links:
        href = url + inner_link['href']
        inner_href.append(href)
    return inner_href

# %%
get_link('Kevin_Bacon')
# inner_link 안에 있는
# Out:
# ['http://en.wikipedia.org/wiki/Kevin_Bacon/wiki/Main_Page',
#  'http://en.wikipedia.org/wiki/Kevin_Bacon/wiki/Wikipedia:Contents',
#  'http://en.wikipedia.org/wiki/Kevin_Bacon/wiki/Portal:Current_events',
#  'http://en.wikipedia.org/wiki/Kevin_Bacon/wiki/Special:Random',
#  'http://en.wikipedia.org/wiki/Kevin_Bacon/wiki/Wikipedia:About',
#  'http://en.wikipedia.org/wiki/Kevin_Bacon/wiki/Help:Contents',
#  'http://en.wikipedia.org/wiki/Kevin_Bacon/wiki/Help:Introduction',
#  'http://en.wikipedia.org/wiki/Kevin_Bacon/wiki/Wikipedia:Community_portal',
#  'http://en.wikipedia.org/wiki/Kevin_Bacon/wiki/Special:RecentChanges',
#  'http://en.wikipedia.org/wiki/Kevin_Bacon/wiki/Wikipedia:File_upload_wizard',
#  'http://en.wikipedia.org/wiki/Kevin_Bacon/wiki/Main_Page',
#  'http://en.wikipedia.org/wiki/Kevin_Bacon/wiki/Special:Search',
#  'http://en.wikipedia.org/wiki/Kevin_Bacon/wiki/Help:Introduction',
#  'http://en.wikipedia.org/wiki/Kevin_Bacon/wiki/Special:MyContributions',
# ...

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
url = 'https://en.wikipedia.org/w/index.php?limit=150&offset=0&profile=default&search=Kevin+bacon&title=Special%3ASearch&fulltext=1&ns0=1'
html = urlopen(url)
bs = BeautifulSoup(html, 'html.parser')
len(bs.findAll('div', {'class': 'searchresult'}))
# Out:
# 150

# %%
dt = []
for t in bs.findAll('div', {'class': 'searchresult'}):
    dt.append(t.text)

# %%
contents = bs.findAll('div', {'class':'searchresult'})[0]
date = bs.findAll('div', {'class':'mw-search-result-data'})

# %%
import numpy as np
import pandas as pd
# df = pd.DataFrame(columns =['contents', 'date'])
# df.columns 

for con, da in zip(contents, date):
    tmp = {'contents':[con.text], 
       'date':[da.text]}
    tmp = pd.DataFrame(tmp)
    df = pd.concat([df, tmp])
df.to_csv('kevin.csv', index=None)
# 저장까지 완

# %%
df
# Out:
#                                             contents                                           date
# 0                                              Kevin     43 KB (3,600 words) - 08:38, 24 March 2023
# 0                                           Norwood   15 KB (1,761 words) - 17:12, 16 December 2022
# 0                                              Bacon     10 KB (253 words) - 09:56, 29 January 2023
# 0   (born July 8, 1958) is an American actor. Kno...       11 KB (981 words) - 01:50, 27 March 2023
# 0                                              Bacon     460 bytes (95 words) - 14:34, 12 June 2022
# 0       has received numerous accolades including...     10 KB (1,088 words) - 23:46, 25 March 2023
# 0                                              Kevin     43 KB (3,600 words) - 08:38, 24 March 2023
# 0                                           Norwood   15 KB (1,761 words) - 17:12, 16 December 2022
# ...

# %%
# 케빈베이컨의 film - 영화 정보 가져오는 크롤링 
# plot 가져오고 plot 가져오고 plot,,
import numpy as np
import pandas as pd
from urllib.request import urlopen
from bs4 import BeautifulSoup
url = "https://en.wikipedia.org/wiki/Kevin_Bacon_filmography"
html = urlopen(url)
bs = BeautifulSoup(html, 'html.parser')

# %%
# 영화목록 -> 제목,링크 가져오기
films = []
base_url = "https://en.wikipedia.org/"
for i in bs.find('table').findAll('a'):
    title = i.text 
    link = base_url + i['href']
    films.append((title, link))

# 링크에서 (plot을 가져오기)
# bs.find('table').findAll('a')
for film in films:
    try:
        title = film[0]
        url = film[1]
        html = urlopen(url)
        bs = BeautifulSoup(html, 'html.parser')
        contents = '' 
        for i in bs.findAll('h2')[1].next_siblings:
            if type(i) is bs4.element.Tag:
                if i.name != 'h2':
                    contents += '\n'+i.text
        data.append((title, contents))  
    except:
        pass

# %%
film = films[0]
film[0]
# Out:
# "National Lampoon's Animal House"

# %%
url = film[0][1]
html = urlopen(url)
bs = BeautifulSoup(html, 'html.parser')

# %%
for i in bs.findAll('h2')[1]:
    for j in i:
        print(j)

# bs.findAll('h2')[1].next_sibling
# Out:
# Plot
# <span class="mw-editsection-bracket">[</span>
# <a href="/w/index.php?title=Animal_House&amp;action=edit&amp;section=1" title="Edit section: Plot">edit</a>
# <span class="mw-editsection-bracket">]</span>

# %%
import bs4
contents = ''
for i in bs.findAll('h2')[1].next_siblings:
    if type(i) is bs4.element.Tag:
        if i.name != 'h2':
            contents += '\n'+i.text
contents
# Out:
# '\nIn fall 1962, Faber College freshmen Larry Kroger and Kent Dorfman seek to pledge a fraternity. Finding themselves ostracized at the prestigious Omega Theta Pi house party, the two visit the Delta Tau Chi house next door; Kent believes he cannot be rejected because his older brother Fred was a member, making him a "legacy." During the party, they meet the slovenly John Blutarsky ("Bluto"), chapter president Robert Hoover, smooth-talking Eric Stratton ("Otter") and his best friend Donald Schoenstein ("Boon"), motorcyclist Daniel Simpson Day ("D-Day"), and Boon\'s girlfriend Katy. Larry and Kent are accepted as Delta pledges and given the fraternity names "Pinto" and "Flounder," respectively.\n\nDelta is on probation due to campus conduct violations and poor academic standing. Wanting to remove the fraternity from campus, Dean Vernon Wormer directs Greg Marmalard, the smug Omega president, to find a justification for him to do so. Various incidents deepen the animosity between Delta
# ...

# %% [markdown]
# ## ch4.

# %%
import requests
from bs4 import BeautifulSoup

# %%
from urllib.request import urlopen
url = 'http://localhost:8000/aaa/'
html = urlopen(url)
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36',
           'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8'}
session = requests.Session()
req = session.get(url, headers=headers)
# 크롤링 시 session 속여야하는데

# %%
# dir(req)
req.headers
# Out:
# {'Date': 'Wed, 29 Mar 2023 08:14:02 GMT', 'Server': 'WSGIServer/0.2 CPython/3.9.13', 'Content-Type': 'text/html; charset=utf-8', 'X-Frame-Options': 'DENY', 'Content-Length': '446', 'X-Content-Type-Options': 'nosniff', 'Referrer-Policy': 'same-origin', 'Cross-Origin-Opener-Policy': 'same-origin'}

# %%
BeautifulSoup(req.text, 'html.parser')
# <Response [404]> 없는 페이지
# 500번대 서버는 잘 돌아가는데 페이지가 이상해
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
# def getPage(url):
#     """
#     Utilty function used to get a Beautiful Soup object from a given URL
#     """
# # 크롤링을 막는 경우.header. session을 이용하여
#     session = requests.Session() # Mozilla: 웹에서 웹서비스에서 가짜로 보이게하는
#     headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36',
#                'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8'}
#     try:
#         req = session.get(url, headers=headers)
#     except requests.exceptions.RequestException:
#         return None
#     bs = BeautifulSoup(req.text, 'html.parser')
#     return bs

# %% [markdown]
# ## ch7.

# %%
from urllib.request import urlretrieve
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen('http://www.pythonscraping.com')
bs =BeautifulSoup(html, 'html.parser')
bs.findAll('img')
imageLoccation = bs.findAll('img')[0]['src']
urlertrieve(imageloction, 'logo.jpg')

# %%
url = "http://pythonscraping.com/pages/warandpeace/chapter1.pdf"
urlretrieve(url, 'chapter1.pdf')
# Out:
# ('chapter1.pdf', <http.client.HTTPMessage at 0x1b8412d00a0>)

# %% [markdown]
# # Selenium 이용한 웹 크롤링

# %%
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from urllib.request import urlretrieve
import time

# %%
# dir(Keys)

# %%
driver = webdriver.Chrome('chromedriver.exe') # 아무것도 없는 가상화
# Out:
# C:\Users\juhae\AppData\Local\Temp\ipykernel_10064\374158378.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe') # 아무것도 없는 가상화

# %%
url = 'https://www.google.com/imghp?h1=ko&ogbl'
driver.get(url)
# driver.get('https://naver.com') # url 띄우기

# %%
# dir(driver)
#  'find_element', 'find_elements', 가 생성됨

# %%
elem = driver.find_element(By.NAME,'q') # q 검색어부분 class 찾기
# import selenium 
# selenium.__version__ # 버전확인

# %%
search_img = '고양이'
elem.send_keys(search_img) # key 찾기

# %%
elem.send_keys(Keys.RETURN)

# %%
# driver.close() # close 하는 것을 추천

# %%
driver.find_elements(By.CSS_SELECTOR,".rg_i.Q4LuWd")[0].click()

img_url = driver.find_element(By.CSS_SELECTOR, '.n3VNCb').get_attribute('src')
urlretrieve(img_url, 'mycat.jpg') # 이미지 저장 완
# Out:
# ('mycat.jpg', <http.client.HTTPMessage at 0x264bf6802e0>)

# %%
driver.find_elements(By.CSS_SELECTOR,".rg_i.Q4LuWd")[3].click()

img_url = driver.find_element(By.CSS_SELECTOR, '.n3VNCb').get_attribute('src')
urlretrieve(img_url, 'mycat2.jpg') # 이미지 저장 완
# Out:
# ('mycat2.jpg', <email.message.Message at 0x264bee8e0d0>)

# %%
# 자동화 웹크롤링 한줄 정리 내용요약
driver = webdriver.Chrome('chromedriver.exe')
url = 'https://www.google.com/imghp?h1=ko&ogbl'
driver.get(url)
elem = driver.find_element(By.NAME,'q')
search_img = '강아지'
elem.send_keys(search_img)
elem.send_keys(Keys.RETURN)

# time.sleep(1) = driver.implicitly_wait(1). 같은 내용
driver.implicitly_wait(1)

images = driver.find_elements(By.CSS_SELECTOR,'.rg_i.Q4LuWd')
cnt =1
for image in images:
    image.click()
    driver.implicitly_wait(1)
    try:
        img_url = driver.find_element(By.CSS_SELECTOR, '.n3VNCb').get_attribute('src')
        urlretrieve(img_url, 'mycat'+str(cnt)+'.jpg')
        cnt +=1
    except:
        pass
    
driver.close()
# Out:
# C:\Users\juhae\AppData\Local\Temp\ipykernel_10064\3335011779.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')

# %%
dir(driver)
# Out:
# ['__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_authenticator_id',
#  '_file_detector',
#  '_get_cdp_details',
#  '_is_remote',
#  '_mobile',
#  '_shadowroot_cls',
#  '_switch_to',
#  '_unwrap_value',
#  '_web_element_cls',
#  '_wrap_value',
#  'add_cookie',
#  'add_credential',
#  'add_virtual_authenticator',
#  'application_cache',
#  'back',
#  'bidi_connection',
#  'capabilities',
#  'caps',
#  'close',
#  'command_executor',
#  'create_options',
#  'create_web_element',
#  'current_url',
#  'current_window_handle',
# ...

# %%
driver = webdriver.Chrome('chromedriver.exe')
url = 'https://www.google.com/imghp?h1=ko&ogbl'
driver.get(url)

# 웹 만들기


elem = driver.find_element(By.NAME,'q')
search_img = '트위드자켓'
elem.send_keys(search_img)
elem.send_keys(Keys.RETURN)
last_height = driver.execute_script("return document.body.scrollHeight;")
while True:
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")
    # driver.implicitly_wait(2)
    time.sleep(2)
    new_height = driver.execute_script("return document.body.scrollHeight;")
    if new_height == last_height:
        try:
            driver.find_element(By.CSS_SELECTOR,'.mye4qd').click()
        except:
            break
    last_height = new_height
    
driver.implicitly_wait(1)
images = driver.find_elements(By.CSS_SELECTOR,'.rg_i.Q4LuWd')
cnt =1
for image in images:
    try:
        image.click()
        driver.implicitly_wait(1)
        img_url = driver.find_element(By.CSS_SELECTOR, '.n3VNCb').get_attribute('src')
        urlretrieve(img_url, 'mycat'+str(cnt)+'.jpg')
        cnt +=1
    except:
        pass
    
driver.close()
# Out:
# C:\Users\juhae\AppData\Local\Temp\ipykernel_10064\704782636.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10064\704782636.py in <module>
#      36         pass
#      37
# ---> 38 driver.close()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in close(self)
#     549                 driver.close()
#     550         """
# --> 551         self.execute(Command.CLOSE)
#     552
#     553     def quit(self) -> None:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     438         response = self.command_executor.execute(driver_command, params)
#     439         if response:
# ...

# %%
last_height
# Out:
# 31626

# %%
last_height = driver.execute_script("return document.body.scrollHeight;")
last_height
# Out:
# 29030
